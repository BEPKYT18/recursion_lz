# %%
import Euclid
import notation
import Pascal
import perfection

# %%
def main():
    Euclid.main()
    notation.main()
    Pascal.main()
    perfection.main()

# %%
if __name__ =='__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 if __name__ =='__main__':
# ----> 2     main()
#
# Cell In[6], line 2, in main()
#       1 def main():
# ----> 2     Euclid.main()
#       3     notation.main()
#       4     Pascal.main()
#
# File c:\Users\User\Desktop\projects\2025\recursion_lz\Euclid.py:11, in main()
#      10 def main():
# ---> 11     a=int(input("Введите первое число для нахождения НОДа: "))
#      12     b=int(input("Введите второе число для нахождения НОДа: "))
#      13     a,b=min(a,b),max(a,b)
#
# ValueError: invalid literal for int() with base 10: ''
